# %% [markdown]
# MY FIRST PYTHON PROJECT

# %% [markdown]
# Build a program that:
# -- Stores students names and scores
# -- Calculates average score
# -- Finds highest and lowest
# -- Tests who passed or failed

# %%
students = ["John", "Amaka", "Chima", "Ogechi", "Frank", "George", "Grace", "Janet", "Anthony", "Desmond"]
scores = [45, 65, 60, 54, 75, 67, 50, 60, 70, 80]

print(students)
#print(score)
# Out:
# ['John', 'Amaka', 'Chima', 'Ogechi', 'Frank', 'George', 'Grace', 'Janet', 'Anthony', 'Desmond']

# %%
students = ["John", "Amaka", "Chima", "Ogechi", "Frank", "George", "Grace", "Janet", "Anthony", "Desmond"]
scores = [45, 65, 60, 54, 75, 67, 50, 60, 70, 80]

#print(students)
print(scores)
# Out:
# [45, 65, 60, 54, 75, 67, 50, 60, 70, 80]

# %%
students = ["John", "Amaka", "Chima", "Ogechi", "Frank", "George", "Grace", "Janet", "Anthony", "Desmond"]
scores = [45, 65, 60, 54, 75, 67, 50, 60, 70, 80]

for i in range( len(students)):
    print(students[i], "scored", scores[i])
# Out:
# John scored 45
# Amaka scored 65
# Chima scored 60
# Ogechi scored 54
# Frank scored 75
# George scored 67
# Grace scored 50
# Janet scored 60
# Anthony scored 70
# Desmond scored 80

# %%
students = ["John", "Amaka", "Chima", "Ogechi", "Frank", "George", "Grace", "Janet", "Anthony", "Desmond"]
scores = [45, 65, 60, 54, 75, 67, 50, 60, 70, 80]
total_score = sum(scores)
number_of_students = len(scores)
average_score = total_score / number_of_students

print("The average score is:", average_score)
# Out:
# The average score is: 62.6

# %%
highest_score = max(scores)
lowest_score = min(scores)

print("highest score is", highest_score)
print("lowest score is", lowest_score)
# Out:
# highest score is 80
# lowest score is 45

# %%
highest_frequency =
