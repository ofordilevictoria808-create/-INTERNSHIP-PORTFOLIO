# %%
CHALLENGE

# %%
def validate_password(password):
     if len(password) < 8:
         return False

     has_upper = False
     has_lower = False
     has_number = False
     has_special = False

     special_chars = "!@#$%^&*"

     for char in password:
         if char.isupper():
             has_upper = True
         elif char.islower():
             has_lower = True
         elif char.isdigit():
             has_number = True
         elif char in special_chars:
             has_special = True
             if has_upper and has_lower and has_number and has_special:
                 return True
                 return False
print(validate_password("Password1!"))
print(validate_password("Password"))
print(validate_password("PASSWORD"))
# Out:
# True
# None
# None

# %%
def validate_password(password):
     if len(password) < 8:
         return False

     has_upper = False
     has_lower = False
     has_number = False
     has_special = False

     special_chars = "!@#$%^&*"

     for char in password:
         if char.isupper():
             has_upper = True
         elif char.islower():
             has_lower = True
         elif char.isdigit():
             has_number = True
         elif char in special_chars:
             has_special = True
             if has_upper and has_lower and has_number and has_special:
                 return True
                 return False
print(validate_password("password1!"))
# Out:
# None

# %%
def validate_password(password):
     if len(password) < 8:
         return False

     has_upper = False
     has_lower = False
     has_number = False
     has_special = False

     special_chars = "!@#$%^&*"

     for char in password:
         if char.isupper():
             has_upper = True
         elif char.islower():
             has_lower = True
         elif char.isdigit():
             has_number = True
         elif char in special_chars:
             has_special = True
             if has_upper and has_lower and has_number and has_special:
                 return True
                 return False
print(validate_password("PASSWORD"))
# Out:
# None

# %% [markdown]
# 2.SHOPPING CART

# %%
shopping_cart = {}
def add_item(cart, item, price, quantity=1):
    if item in cart:
        cart[item]["quantity"] += quantity
    else:
        cart[item] = {"price": price, "quantity": quantity}
        
        def remove_item(cart, item, quantity):
            if item in cart:
               if cart[item]["quantity"] <= quantity:
                   del cart[item]
               else:
                 cart[item]["quantity"] -= quantity
                   print(f"item not found in cart")


def calculation_total(cart):
    total = 0

    for item in cart:
        price = cart[item]["price"]
        quantity = cart[item]["quantity"]
        total += price * quantity

        return total

def apply_discount(total, discount_percent):
    discount = total * (discount_percent / 100)
    return total - discount


#test functions
add_item(shopping_cart, "apple", 50, 3)
add_item(shopping_cart, "banana",  30, 2)
add_item(shopping_cart, "apple", 50, 1)

print(shopping_cart)

remove_item(shopping_cart, "apple", 50, 3)
print(shopping_cart)

total = calculate_total_(shopping_cart)
print(f"Total: ${total:.2f}")

discounted = apply_discounted(total, 10)
print(f"After 10% discount: ${discounted:.2f}")
# Out:
# {'apple': {'price': 50, 'quantity': 4}, 'banana': {'price': 30, 'quantity': 2}}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[105], line 38
#      34 add_item(shopping_cart, "apple", 50, 1)
#      36 print(shopping_cart)
# ---> 38 remove_item(shopping_cart, "apple", 50, 3)
#      39 print(shopping_cart)
#      41 total = calculate_total_(shopping_cart)
#
# NameError: name 'remove_item' is not defined
