# %%
#mylib.py

def multiply(a, b):
    return a * b

def is_even(numbers):
    if number % 2 == 0:
       return True
    else:
       return False

# %%
#vin.py

# %%
def multiply_numbers(a, b):
    return a * b

result = multiply_numbers(5, 7)
print(result)

def is_even(number):
    if number % 2 == 0:
       return True
    else:
       return False
print("is 7 even?", is_even(7))
# Out:
# 35
# is 7 even? False

# %% [markdown]
# They are as follows:
# 1. Matplotlib
# - It is used mainly for crating animated, and interactive visualization
# - it can also be used to create graphs
#
# 2. Seaborn
# - Similar to matplotlib, it is used for the provision of high level interface for
#   the creation of attractive statistical graphics
#
# 3. Django
# - It is mainly beneficial for developing web applications and APIs.
#
# 4. Scikit-Learn(ML)
# - This is used in traditional industry to create machine learning algorithms, such as
#   classification, regression, clustering and dimensional reduction.
#
# 5. OpenCV
# - Used for computer vision tasks, image processing, and video analytics.
